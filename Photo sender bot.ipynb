# %%
import os
import telebot # pip install pyTelegramBotAPI
import pandas as pd
import csv
from datetime import datetime

bot = telebot.TeleBot("") # BotFather

@bot.message_handler(commands=["start"])
def start(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    bot.register_next_step_handler(bot.send_message(message.chat.id, "GO", reply_markup = keyboard), point1)
    
# a simple example of how to make sequential sends of something

def point1(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://perito.media/uploads/post/image/3d31945c19878a4a9de5fb05b31e2968afeb1464af0b7381e565ba740901553a/main_126044684236316232206_DSC_1100.JPG")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point2)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point1)


def point2(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://natworld.info/wp-content/uploads/2018/02/vodosvinka-ili-kapibara.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point3)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point2)
def point3(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://i.ucrazy.ru/files/pics/2022.09/photo166253975420.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point4)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point3)
        
def point4(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://sun1-83.userapi.com/c635106/v635106215/3ffbc/ORt-5dSF5NI.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point5)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point4)
        
def point5(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://i.pinimg.com/originals/70/85/d0/7085d0fa5fe3b93ed7ebbc8d46f9b4e8.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point6)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point5)
        
def point6(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://static.euronews.com/articles/stories/06/32/70/76/1440x810_cmsv2_2be0d818-48e2-52de-8787-c024d10c435d-6327076.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point7)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point6)
        
def point7(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://ichef.bbci.co.uk/news/640/amz/worldservice/live/assets/images/2015/11/06/151106142050_capybara_logo_624x351_mattround_nocredit.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point8)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point7)
        
def point8(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://www.topnews.ru/wp-content/uploads/2021/08/kapibara-3.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point9)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point8)
        
def point9(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://static.kulturologia.ru/files/u18476/AnimalsLikeCapybaras-1.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point10)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point9)
        
def point10(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://oir.mobi/uploads/posts/2021-05/1620853950_58-oir_mobi-p-kapibara-detenish-zhivotnie-krasivo-foto-62.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point11)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point10)
        
def point11(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://na-dostupnom.ru/wp-content/uploads/2021/12/aHpnkCFosvI.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point12)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point11)
        
def point12(message):
    keyboard = telebot.types.ReplyKeyboardMarkup(row_width=1, resize_keyboard=True)
    button_phone = telebot.types.KeyboardButton(text="Еще?")
    keyboard.add(button_phone)
    # если ответ верен
    if message.text == "Еще?":
        # пишем об этом пользвоателю и задаем следующие вопрос
        answer = bot.send_photo(message.chat.id, "https://s9.travelask.ru/uploads/post/000/025/923/main_image/full-2af6fc8c8210d9ac04b6f99f426b45bd.jpg")

        # в ответ на сообщение просим вызвать функцию point2
        bot.register_next_step_handler(answer, point1)
    else:
        # пишем, что ответ неверен
        answer = bot.send_message(message.chat.id, "Нет, попробуйте еще раз...")
        # в ответ на сообщение просим вызвать функцию point1
        bot.register_next_step_handler(answer, point12)

bot.polling()
